# %%
students=[]
for i in range(2):
    name=input("enter name:")
    role=str(input("enter role:"))
    students.append((name, role))
    print("\n students")
    for student in students:
        print(student)
# Out:
#  students
# ('aneesha', 'python ai developer')
#
#  students
# ('aneesha', 'python ai developer')
# ('vanaja', 'web developer')

# %%
student_skills = set(input("Enter your skills: ").split())
job_skills = {"Python", "SQL", "Git"}

matched = student_skills & job_skills
missing = job_skills - student_skills

print("\nMatched Skills:", matched)
print("Missing Skills:", missing)
# Out:
# Matched Skills: set()
# Missing Skills: {'Python', 'SQL', 'Git'}

# %% [markdown]
# # project

# %%
student={
    'name':'aneesha',
    'cgpa':8.0,
    'role':'trainee',
    'age':21,
    'dob':'2005-05-05',
    'doj':'2026-01-05',
    'batch_type':'spark',
    'location ':'bangalore',
    'amount':1000000,
    'skills':['python','sql','git','AI','python']
    }
print(student['amount'])
print(student['cgpa'])
print(student['role'])
print(student['role'][-1])
print(student['skills'])
print(student)
print(student.update({    'skills':['python','sql','git','AI','python']})) 
print(student.update({    'intern':['python','sql','git','AI','python']}))
print(student.update({
    ('intern_id','roll_no'):['238x1yhj089','228x1a0406']
}))
print(student)
# Out:
# 1000000
# 8.0
# trainee
# e
# ['python', 'sql', 'git', 'AI', 'python']
# {'name': 'aneesha', 'cgpa': 8.0, 'role': 'trainee', 'age': 21, 'dob': '2005-05-05', 'doj': '2026-01-05', 'batch_type': 'spark', 'location ': 'bangalore', 'amount': 1000000, 'skills': ['python', 'sql', 'git', 'AI', 'python']}
# None
# None
# None
# {'name': 'aneesha', 'cgpa': 8.0, 'role': 'trainee', 'age': 21, 'dob': '2005-05-05', 'doj': '2026-01-05', 'batch_type': 'spark', 'location ': 'bangalore', 'amount': 1000000, 'skills': ['python', 'sql', 'git', 'AI', 'python'], 'intern': ['python', 'sql', 'git', 'AI', 'python'], ('intern_id', 'roll_no'): ['238x1yhj089', '228x1a0406']}

# %%
for i in range(2):
    print(f"\nenter student {i+1} details:")
# Out:
# enter student 1 details:
#
# enter student 2 details:
