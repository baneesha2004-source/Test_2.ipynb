# %%
print("algonex is welcoming you to the world of programming")
# Out:
# algonex is welcoming you to the world of programming

# %%
print('algonex is welcoming you to the world of programming')
# Out:
# algonex is welcoming you to the world of programming

# %%
print("algonex\n is welcoming you to the world's of programming")
print("algonex\t is welcoming you to the world of programming")
print("algonex\t is welcoming you to the\b world's of programming")
# Out:
# algonex
#  is welcoming you to the world's of programming
# algonex	 is welcoming you to the world of programming
# algonex	 is welcoming you to th world's of programming

# %%
t=100 #int
t=23.38 #float
t="algonex" #string
t=True #boolean
t=None #null
print(t)
# Out:
# None

# %%
numbers=[1,2,3,4,5]# list
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
student=("anee",21,"python")
print(student[-2])
# Out:
# 21

# %%
t=(None,[2.0,True],'4',5) #tuple
print(t[1])
# Out:
# [2.0, True]

# %%
T={123,4,3,34,3,44,3,53,4,3,4} #set
print(t)
# Out:
# (None, [2.0, True], '4', 5)

# %%
t={'name':'anee','age':[21,6,7,8],'is_programming':True} #dictionary
print(t['name'])
# Out:
# anee

# %%
print("welcome to algonex! + 'you joined at '+ internship")
print("aneesha's"+"house is so big")
rating=4.5
print("algonex ratingis "+str(rating))
# Out:
# welcome to algonex! + 'you joined at '+ internship
# aneesha'shouse is so big
# algonex ratingis 4.5

# %%
print("algonex it solutions is in marathahalli for python and data track with internship")
print("algonex it solutions\b is in\t marathahalli \nfor python and data track with internship")
# Out:
# algonex it solutions is in marathahalli for python and data track with internship
# algonex it solution is in	 marathahalli
# for python and data track with internship

# %%
h=1234
# int to float
# h=float(h) #permanent
j=float(h) #temporary
print(h)

# int to string
h=str(h)
print(h,"type is",type(h))
# Out:
# 1234
# 1234 type is <class 'str'>

# %%
# float
h=12.5
print(h)
# float to int
h=int(h)
print(h,type(h))
# Out:
# 12.5
# 12 <class 'int'>

# %%
str="       algonex it solutions       "
str=str.strip()
str=str.rstrip()
str=str.lstrip()
print(str)


# str to int
# str=int(str)
# split -convert into list
str=str.split()
# str to tuple
str=tuple(str)
print(str)
str=list(str)
print(str)
# Out:
# algonex it solutions
# ('algonex', 'it', 'solutions')
# ['algonex', 'it', 'solutions']

# %%
d=12.99
print(d)
d=int(d)
print(d)
# Out:
# 12.99
# 12

# %%
h=[1,2,3,4,"naveen",[23,34,22],True,34.4]
print(h[4])
print(h[0:3])# h[start:end-1]
# Out:
# naveen
# [1, 2, 3]

# %%
k=[23,34,45,67,56,57,58,98]
print(k[2])
print(k[2:])
print(k[:2])
print(k[2:10])
print(k[2:10:1])
# Out:
# 45
# [45, 67, 56, 57, 58, 98]
# [23, 34]
# [45, 67, 56, 57, 58, 98]
# [45, 67, 56, 57, 58, 98]

# %%
print(k)#[23,43,56,57,59,67]
k[2]=200
l=[123,34,45]
k.append(l)
k.append(1000)
print(k)
# Out:
# [23, 34, 200, 67, 56, 57, 58, 98, [123, 34, 45]]
# [23, 34, 200, 67, 56, 57, 58, 98, [123, 34, 45], [123, 34, 45], 1000]

# %%
k=[23,43,56,57,59,67]
k.append(1000)
k.extend(l)
k.insert(2,500)


# delete
k.remove(57)
k.pop(5) 
del k[2]       
print(k)
# Out:
# [23, 43, 56, 59, 1000, 123, 34, 45]
