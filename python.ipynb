# %%
game={
    "name":"cricket",
    "players":["karthik","sachin","dhoni"],
    "roles":["batsman"]

}
print(game["name"])
for i in game:
    print(i,'-',game[i])
    print(game.keys(),game.values())
# Out:
# cricket
# name - cricket
# dict_keys(['name', 'players', 'roles']) dict_values(['cricket', ['karthik', 'sachin', 'dhoni'], ['batsman']])
# players - ['karthik', 'sachin', 'dhoni']
# dict_keys(['name', 'players', 'roles']) dict_values(['cricket', ['karthik', 'sachin', 'dhoni'], ['batsman']])
# roles - ['batsman']
# dict_keys(['name', 'players', 'roles']) dict_values(['cricket', ['karthik', 'sachin', 'dhoni'], ['batsman']])

# %%
game={
    "name":"cricket",
    "players":["karthik","sana","dhana"],
    "roles":["batsman"]

}
print(game["name"])
#for p,q in game.items():
 #     print(p,q)
print("name"in game)
print(len(game))
# Out:
# cricket
# True
# 3

# %%
algonex={
    "s1":{
        "name":"python",
        "duration":"2 months"
    },
    "s2":{
        "name":["rava","fathima","dheeraj"],
        "duration":"3 months"
    }
}
print(algonex["s1"]["name"])
print(algonex["s1"]["duration"])
print(algonex["s2"]["name"][1])
print(algonex["s2"]["name"][0:2+1])
print(algonex["s2"]["duration"])
# Out:
# python
# 2 months
# fathima
# ['rava', 'fathima', 'dheeraj']
# 3 months
